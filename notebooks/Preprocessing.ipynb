# %% [markdown]
# ## Preprocessing

# %%
# Importing necessary libraries
import numpy as np
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Read file

# %%
#reading the .csv file and declare datatype to avoid low memory issues
df = pd.read_csv("../data/interim/trec07.csv",dtype='unicode')

# %% [markdown]
# ### Handling Null Values

# %%
# replacing na values
df["Return-Path"].fillna("unknown", inplace = True) 
df["Message-ID"].fillna("unknown", inplace = True) 
df["From"].fillna("unknown", inplace = True) 
df["Reply-To"].fillna("unknown", inplace = True) 
df["To"].fillna("unknown", inplace = True) 
df["Date"].fillna("unknown", inplace = True) 
df["X-Mailer"].fillna("unknown", inplace = True)
df["MIME-Version"].fillna("0", inplace = True)
df["Content-Type"].fillna("unknown", inplace = True)
df["X-Priority"].fillna("0", inplace = True)
df["X-MSMail-Priority"].fillna("0", inplace = True)
df["Status"].fillna("0", inplace = True)
df["Content-Length"].fillna("0", inplace = True)
df["Content-Transfer-Encoding"].fillna("unknown", inplace = True)
df["Lines"].fillna("0", inplace = True)
df = df.dropna(axis = 0,how ='any')
df
# Out:
#                                              Return-Path  \
# 0            <Phoebesiemensclaudia@victorytulsa.org>\r\n
# 1       <samba-cvs-bounces+ktwarwic=speedy.uwaterloo....
# 2                 <r-help-bounces@stat.math.ethz.ch>\r\n
# 3                         <qepcw9y7j@plumcopper.com>\r\n
# 4                   <speakup-bounces@braille.uwo.ca>\r\n
# ...                                                  ...
# 62498   <samba-technical-bounces+ktwarwic=speedy.uwat...
# 62499   <space_shuttle-jump-ktwarwic=speedy.uwaterloo...
# 62500                    <LoansAWBC@controldraw.net>\r\n
# 62501   <samba-technical-bounces+ktwarwic=speedy.uwat...
# 62502             <r-help-bounces@stat.math.ethz.ch>\r\n
#
#                                               Message-ID  \
# 0                                                unknown
# 1                                                unknown
# 2              <C2779203.E6%r.turner@auckland.ac.nz>\r\n
# 3                <462809ee-qepcw9y7j@plumcopper.com>\r\n
# 4                                                unknown
# ...                                                  ...
# 62498                                            unknown
# 62499   <CE7E4CE628C79245A57591B3A970BB4A07E2A41C@NYC...
# 62500                                            unknown
# 62501                                            unknown
# 62502   <122383.93801.qm@web26004.mail.ukl.yahoo.com>...
#
#                                                     From  \
# 0       "Gilda Isaac" <Phoebesiemensclaudia@victorytu...
# 1                                   jpeach@samba.org\r\n
# 2              Rolf Turner <r.turner@auckland.ac.nz>\r\n
# 3                 "David" <qepcw9y7j@plumcopper.com>\r\n
# 4         Shane <shane-keyword-speakup.aca783@cm.nu>\r\n
# ...                                                  ...
# 62498                   Luke Howard <lukeh@padl.com>\r\n
# 62499   "CBS Space News" <space_shuttle-ktwarwic=spee...
# 62500    "A.W.B.C_Loans" <LoansAWBC@controldraw.net>\r\n
# 62501           Michael B Allen <mba2000@ioplex.com>\r\n
# 62502   CHANDRAMOULI BANERJEE <cmban_30@yahoo.co.uk>\r\n
#
#                                                 Reply-To  \
# 0                                                unknown
# 1                    samba-technical@lists.samba.org\r\n
# 2                                                unknown
# 3                                                unknown
# 4       "Speakup is a screen review system for Linux....
# ...                                                  ...
# 62498                                 lukeh@padl.com\r\n
# 62499                                            unknown
# 62500                                            unknown
# 62501                                            unknown
# 62502                                            unknown
#
#                                                       To  \
# 0                          theorize@plg.uwaterloo.ca\r\n
# 1                                samba-cvs@samba.org\r\n
# 2                   Rhelp <r-help@stat.math.ethz.ch>\r\n
# 3       "Subscriber" <producttestpanel@speedy.uwaterl...
# 4       "Speakup is a screen review system for Linux....
# ...                                                  ...
# 62498                                jerry@samba.org\r\n
# 62499                   ktwarwic@speedy.uwaterloo.ca\r\n
# 62500         <producttestpanel@speedy.uwaterloo.ca>\r\n
# 62501          "yang mikey" <mikeyredmoon@gmail.com>\r\n
# 62502                       r-help@stat.math.ethz.ch\r\n
#
#                                          Submitting Host  \
# 0                                                 riffle
# 1                   dp.samba.org (localhost [127.0.0.1])
# 2                 130.216.104.237 ([130.216.104.237]) by
# 3       plumcopper.com (plumcopper.com [208.66.235.190])
# 4        shane by continuum.cm.nu with local (Exim 4.63)
# ...                                                  ...
# 62498       au.padl.com (localhost.padl.com [127.0.0.1])
# 62499    cbsig.com (web145.bc.cbsig.net [65.244.48.145])
# 62500  controldraw.net (r01h05.chitay-zdes.ru [89.208...
# 62501  quark.foo.net (c-69-142-196-170.hsd1.nj.comcas...
# 62502  [122.167.133.64] by web26004.mail.ukl.yahoo.co...
#
#                                                Subject                  Date  \
# 0                            alan liverpool alkane\r\n   Sun, 17 Jun 2007 01
# 1                                           svn commit         2007-06-13 20
# 2                          [R] quartz() on MAC OSX\r\n   Mon, 21 May 2007 18
# 3                                        Final Attempt   Thu, 19 Apr 2007 19
# 4                                                   Re   Wed, 09 May 2007 10
# ...                                                ...                   ...
# 62498                                               Re   Fri, 20 Apr 2007 00
# 62499                                4/11 1145a Update   Wed, 11 Apr 2007 11
# 62500                 FINANCE certificate enclosed\r\n   Wed, 18 Apr 2007 10
# 62501                                               Re   Sun, 10 Jun 2007 23
# 62502   [R] Need Help on Joining 2 text files in R\r\n   Wed, 23 May 2007 12
#
#                                                 X-Mailer MIME-Version  \
# 0                                                unknown            0
# 1                                                unknown            0
# 2                                                unknown            0
# 3                                                unknown      1.0\r\n
# 4                                                unknown            0
# ...                                                  ...          ...
# 62498                                            unknown      1.0\r\n
# 62499                                            unknown      1.0\r\n
# 62500                                            unknown            0
# 62501   Sylpheed 2.4.0 (GTK+ 2.10.4; i686-pc-linux-gn...            0
# 62502                                            unknown      1.0\r\n
#
#                                Content-Type X-Priority X-MSMail-Priority  \
# 0          text/plain; charset=us-ascii\r\n          0                 0
# 1             text/plain; charset=UTF-8\r\n          0                 0
# 2        text/plain; charset="us-ascii"\r\n          0                 0
# 3           text/plain; charset="UTF-8"\r\n          0                 0
# 4        text/plain; charset="us-ascii"\r\n          0                 0
# ...                                     ...        ...               ...
# 62498      text/plain; charset=US-ASCII\r\n          0                 0
# 62499                        text/html;\r\n          0                 0
# 62500   text/html; charset="iso-8859-1"\r\n          0                 0
# 62501      text/plain; charset=US-ASCII\r\n          0                 0
# 62502    text/plain; charset="us-ascii"\r\n          0                 0
#
#        Status Content-Length Content-Transfer-Encoding     Lines Label hops
# 0           0              0                  7bit\r\n         0     1    3
# 1           0              0                  8bit\r\n         0     0    2
# 2           0              0                  7bit\r\n         0     0    9
# 3       O\r\n       1183\r\n                  8bit\r\n    40\r\n     1    1
# 4           0              0                  7bit\r\n         0     0    6
# ...       ...            ...                       ...       ...   ...  ...
# 62498   O\r\n        462\r\n                   unknown    18\r\n     0    4
# 62499   O\r\n       6955\r\n      quoted-printable\r\n   180\r\n     0    1
# 62500   O\r\n       2514\r\n                   unknown    43\r\n     1    1
# 62501       0              0                  7bit\r\n         0     0    4
# 62502       0              0                  7bit\r\n         0     0    4
#
# [62394 rows x 19 columns]

# %%
#check if there is any other null values
df.isnull().sum()
# Out:
# Return-Path                  0
# Message-ID                   0
# From                         0
# Reply-To                     0
# To                           0
# Submitting Host              0
# Subject                      0
# Date                         0
# X-Mailer                     0
# MIME-Version                 0
# Content-Type                 0
# X-Priority                   0
# X-MSMail-Priority            0
# Status                       0
# Content-Length               0
# Content-Transfer-Encoding    0
# Lines                        0
# Label                        0
# hops                         0
# dtype: int64

# %%
#removing duplicates and removing \n characters and re
df.drop_duplicates()
df = df.replace("\n","",regex = True)
df = df.replace("re :","",regex = True)

# %%
df.to_csv('preprocessed.csv',index=False)
